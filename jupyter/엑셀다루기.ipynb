# %%
import pandas as pd

# %% [markdown]
# ### CSV

# %%
df = pd.DataFrame([
    ['홍길동', 80, 90, 100],
    ['김길동', 80, 70, 90],
    ['최길동', 80, 60, 50]
], columns=['이름', '국어', '영어', '수학'])
df
# Out:
#     이름  국어  영어   수학
# 0  홍길동  80  90  100
# 1  김길동  80  70   90
# 2  최길동  80  60   50

# %%
# csv로 저장
df.to_csv('score.csv')  # 인덱스명 제외 (, index=False)

# %%
df2 = pd.read_csv('score.csv', index_col=0) # 첫번째 열을 인덱스로 지정
df2
# Out:
#     이름  국어  영어   수학
# 0  홍길동  80  90  100
# 1  김길동  80  70   90
# 2  최길동  80  60   50

# %%
# 한글 깨지는 문제 
# 인코딩을 ms949/cp949
df.to_csv('score2.csv', encoding='ms949') # 엑셀에선 안깨지지만, 주피터에서는 깨짐
# 메모장은 두가지 다 깨짐없이 열어볼 수 있음

# %%
df3 = pd.read_csv('score2.csv', encoding='ms949', index_col=0) # 유니코드가 아니면 아예 읽어오지 못함, 인코딩 옵션 줘야함

# %%
df3
# Out:
#     이름  국어  영어   수학
# 0  홍길동  80  90  100
# 1  김길동  80  70   90
# 2  최길동  80  60   50

# %%
# 합계 출력
df3.iloc[:, 1:4].sum(axis=1)
# Out:
# 0    270
# 1    240
# 2    190
# dtype: int64

# %%
# 평균 출력
df3.iloc[:, 1:4].mean(axis=1)
# Out:
# 0    90.000000
# 1    80.000000
# 2    63.333333
# dtype: float64

# %%
# 평균 열을 추가
df3['평균'] = df3.iloc[:, 1:4].mean(axis=1)

# %%
df3
# Out:
#     이름  국어  영어   수학         평균
# 0  홍길동  80  90  100  90.000000
# 1  김길동  80  70   90  80.000000
# 2  최길동  80  60   50  63.333333

# %%
# 과목평균
df3.iloc[:, 1:].mean(axis=0)
# Out:
# 국어    80.000000
# 영어    73.333333
# 수학    80.000000
# 평균    77.777778
# dtype: float64

# %%
# 과목 평균행 추가
df3.loc[3] = df3.iloc[:, 1:].mean(axis=0)

# %%
df3
# Out:
#     이름    국어         영어     수학         평균
# 0  홍길동  80.0  90.000000  100.0  90.000000
# 1  김길동  80.0  70.000000   90.0  80.000000
# 2  최길동  80.0  60.000000   50.0  63.333333
# 3  NaN  80.0  73.333333   80.0  77.777778

# %%
df3.drop('과목평균', axis=0, inplace=True)

# %%
df3
# Out:
#     이름    국어         영어     수학         평균
# 0  홍길동  80.0  90.000000  100.0  90.000000
# 1  김길동  80.0  70.000000   90.0  80.000000
# 2  최길동  80.0  60.000000   50.0  63.333333
# 3  NaN  80.0  73.333333   80.0  77.777778

# %%
# NaN -> 과목평균 수정
df3.loc[3,'이름'] = '과목평균'
df3
# Out:
#      이름    국어         영어     수학         평균
# 0   홍길동  80.0  90.000000  100.0  90.000000
# 1   김길동  80.0  70.000000   90.0  80.000000
# 2   최길동  80.0  60.000000   50.0  63.333333
# 3  과목평균  80.0  73.333333   80.0  77.777778

# %%
df3.to_csv('score_result.csv', index=False)

# %% [markdown]
# ### Excel

# %%
df = pd.read_excel('학생성적.xlsx')
df
# Out:
#    학생명   국어  영어   수학         평균
# 0  홍길동   90  80  100  90.000000
# 1  김길동   80  90   70  80.000000
# 2  최길동  100  90  100  96.666667
# 3  박길동   60  50   70  60.000000
# 4  이길동   70  60   80  70.000000

# %%
# 첫번째 시트
df1 = pd.read_excel('학생성적.xlsx', sheet_name=0)
df1
# Out:
#    학생명   국어  영어   수학         평균
# 0  홍길동   90  80  100  90.000000
# 1  김길동   80  90   70  80.000000
# 2  최길동  100  90  100  96.666667
# 3  박길동   60  50   70  60.000000
# 4  이길동   70  60   80  70.000000

# %%
# 두번째 시트
df2 = pd.read_excel('학생성적.xlsx', sheet_name=1)
df2
# Out:
#    학생명   국어  영어   수학         평균
# 0  홍길동   90  60  100  83.333333
# 1  김길동   90  55   70  71.666667
# 2  최길동  100  90   80  90.000000
# 3  박길동   60  50   70  60.000000
# 4  이길동   70  60   80  70.000000

# %%
df2 = pd.read_excel('학생성적.xlsx', sheet_name='기말고사')
df2
# Out:
#    학생명   국어  영어   수학         평균
# 0  홍길동   90  60  100  83.333333
# 1  김길동   90  55   70  71.666667
# 2  최길동  100  90   80  90.000000
# 3  박길동   60  50   70  60.000000
# 4  이길동   70  60   80  70.000000

# %% [markdown]
# ### Excel 저장
# - ExcelWriter 객체 생성
# - DataFrame 객체를 지정된 시트에 쓰기
# - ExcelWriter 객체 저장

# %%
# 객체 생성
ew = pd.ExcelWriter('학생성적2.xlsx', engine='xlsxwriter')
# 시트에 쓰기
df1.to_excel(ew, index=False)
# 저장
ew.save()

# %%
# 객체 생성
ew = pd.ExcelWriter('학생성적2.xlsx', engine='xlsxwriter')
# 시트에 쓰기
df1.to_excel(ew, index=False, sheet_name='중간고사') #시트명 지정
df2.to_excel(ew, index=False, sheet_name='기말고사')
# 저장
ew.save()

# %%
# 여러개의 엑셀 파일을 한꺼번에 열기
files = ['XX푸드_강남.xlsx', 'XX푸드_종로.xlsx', 'XX푸드_홍대.xlsx']
df = pd.DataFrame()
for file in files:
    df = df.append(pd.read_excel(file))
df
# Out:
# C:\Users\tjoeun-jr-902-02\AppData\Local\Temp\ipykernel_10108\783796298.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_excel(file))
# C:\Users\tjoeun-jr-902-02\AppData\Local\Temp\ipykernel_10108\783796298.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_excel(file))
# C:\Users\tjoeun-jr-902-02\AppData\Local\Temp\ipykernel_10108\783796298.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_excel(file))
#   지점명         일자    상품     금액
# 0  강남 2020-12-01   샐러드  50000
# 1  강남 2020-12-02  스테이크  80000
# 2  강남 2020-12-03  스테이크  80000
# 3  강남 2020-12-04  스파게티  90000
# 4  강남 2020-12-05   돈까스  70000
# 0  종로 2020-12-01   샐러드  50000
# 1  종로 2020-12-02  스테이크  80000
# 2  종로 2020-12-03  스테이크  80000
# 3  종로 2020-12-04  스파게티  90000
# 4  종로 2020-12-05   돈까스  70000
# 0  홍대 2020-12-01   샐러드  50000
# 1  홍대 2020-12-02  스테이크  80000
# 2  홍대 2020-12-03  스테이크  80000
# 3  홍대 2020-12-04  스파게티  90000
# 4  홍대 2020-12-05   돈까스  70000

# %%
import glob
glob.glob('./XX푸드_*.xlsx')
# Out:
# ['.\\XX푸드_강남.xlsx', '.\\XX푸드_종로.xlsx', '.\\XX푸드_홍대.xlsx']

# %%
df = pd.DataFrame()
for file in glob.glob('./XX푸드_*.xlsx'):
    df = df.append(pd.read_excel(file))
df
# Out:
# C:\Users\tjoeun-jr-902-02\AppData\Local\Temp\ipykernel_10108\1226859918.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_excel(file))
# C:\Users\tjoeun-jr-902-02\AppData\Local\Temp\ipykernel_10108\1226859918.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_excel(file))
# C:\Users\tjoeun-jr-902-02\AppData\Local\Temp\ipykernel_10108\1226859918.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_excel(file))
#   지점명         일자    상품     금액
# 0  강남 2020-12-01   샐러드  50000
# 1  강남 2020-12-02  스테이크  80000
# 2  강남 2020-12-03  스테이크  80000
# 3  강남 2020-12-04  스파게티  90000
# 4  강남 2020-12-05   돈까스  70000
# 0  종로 2020-12-01   샐러드  50000
# 1  종로 2020-12-02  스테이크  80000
# 2  종로 2020-12-03  스테이크  80000
# 3  종로 2020-12-04  스파게티  90000
# 4  종로 2020-12-05   돈까스  70000
# 0  홍대 2020-12-01   샐러드  50000
# 1  홍대 2020-12-02  스테이크  80000
# 2  홍대 2020-12-03  스테이크  80000
# 3  홍대 2020-12-04  스파게티  90000
# 4  홍대 2020-12-05   돈까스  70000

# %%
# 인덱스명이 중복
df.loc[4, :] # 정확하게는 인덱스가 아닌 레이블을 의미하기 때문에 중복됨
# Out:
#   지점명         일자   상품     금액
# 4  강남 2020-12-05  돈까스  70000
# 4  종로 2020-12-05  돈까스  70000
# 4  홍대 2020-12-05  돈까스  70000

# %%
df.iloc[4, :] # 숫자인덱스라서 중복되지 않음
# Out:
# 지점명                     강남
# 일자     2020-12-05 00:00:00
# 상품                     돈까스
# 금액                   70000
# Name: 4, dtype: object

# %%
# 인덱스 초기화
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#    지점명         일자    상품     금액
# 0   강남 2020-12-01   샐러드  50000
# 1   강남 2020-12-02  스테이크  80000
# 2   강남 2020-12-03  스테이크  80000
# 3   강남 2020-12-04  스파게티  90000
# 4   강남 2020-12-05   돈까스  70000
# 5   종로 2020-12-01   샐러드  50000
# 6   종로 2020-12-02  스테이크  80000
# 7   종로 2020-12-03  스테이크  80000
# 8   종로 2020-12-04  스파게티  90000
# 9   종로 2020-12-05   돈까스  70000
# 10  홍대 2020-12-01   샐러드  50000
# 11  홍대 2020-12-02  스테이크  80000
# 12  홍대 2020-12-03  스테이크  80000
# 13  홍대 2020-12-04  스파게티  90000
# 14  홍대 2020-12-05   돈까스  70000

# %%
# 스테이크만 출력
#df.loc[df['상품']=='스테이크']
#df[df['상품']=='스테이크']
df[df.loc[:,'상품'] == '스테이크']
# Out:
#    지점명         일자    상품     금액
# 1   강남 2020-12-02  스테이크  80000
# 2   강남 2020-12-03  스테이크  80000
# 6   종로 2020-12-02  스테이크  80000
# 7   종로 2020-12-03  스테이크  80000
# 11  홍대 2020-12-02  스테이크  80000
# 12  홍대 2020-12-03  스테이크  80000

# %%
# 스테이크의 판매금액 합계
# df.loc[df['상품'] == '스테이크'].loc[:, '금액'].sum()
# df.loc[df['상품'] == '스테이크'].iloc[:, 3].sum()
df.loc[df['상품'] == '스테이크']['금액'].sum()
# Out:
# 480000

# %%
# 엑셀에 차트 넣기 (참고 URL)
# https://xlsxwriter.readthedocs.io/

# %%
# 차트 예시
# 객체 생성
ew = pd.ExcelWriter('학생성적2.xlsx', engine='xlsxwriter')
# 시트에 쓰기
df1.to_excel(ew, index=False, sheet_name='중간고사') #시트명 지정
df2.to_excel(ew, index=False, sheet_name='기말고사')

# workbook, worksheet 생성
workbook = ew.book
worksheet = ew.sheets['중간고사']

# 차트 종류
chart = workbook.add_chart({'type':'column'})

# 데이터 범위 지정
chart.add_series({'name':'=중간고사!$B$1', 'categories':'=중간고사!$A$2:$A$6', 'values':'=중간고사!$B$2:$B$6'})  
chart.add_series({'name':'=중간고사!$B$1', 'categories':'=중간고사!$A$2:$A$6', 'values':'=중간고사!$C$2:$C$6'})
chart.add_series({'name':'=중간고사!$B$1', 'categories':'=중간고사!$A$2:$A$6', 'values':'=중간고사!$D$2:$D$6'})
# 차트 삽입
worksheet.insert_chart('F2', chart)
# 저장
ew.save()
