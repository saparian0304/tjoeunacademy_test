# %%
# 1. 데이터 로드
import pandas as pd
df = pd.read_csv('Jeju.csv', encoding='ms949')

# %%
# 2. 상위 5개 출력
import pandas as pd
data = pd.read_csv('Jeju.csv', encoding='ms949')
print(data.head())
# Out:
#       id          일자   시도명  읍면동명         거주인구       근무인구        방문인구  \
# 0  22448  2018-01-01   제주시   도두동    32249.987   3418.266  102709.092
# 1  22449  2018-01-01   제주시   외도동   213500.997  10341.172  112692.789
# 2  22450  2018-01-01   제주시  이도2동  1212382.218  96920.834  541194.481
# 3  22451  2018-01-01   제주시  일도1동    33991.653   6034.253   72155.919
# 4  22452  2018-01-01  서귀포시   대천동   155036.925   9403.969  150882.409
#
#         총 유동인구   평균 속도  평균 소요 시간  평균 기온  일강수량  평균 풍속
# 0   138377.345  39.556    29.167    5.0   0.0    2.5
# 1   336534.958  32.900    30.900    5.0   0.0    2.5
# 2  1850497.533  29.538    35.692    2.9   0.0    2.4
# 3   112181.825  30.000    23.500    2.9   0.0    2.4
# 4   315323.303  41.583    14.375    5.1   0.0    2.3

# %%
# 3. 데이터의 행과 열 출력
import pandas as pd 
data = pd.read_csv('Jeju.csv', encoding='ms949')
print(data.columns)
print(data.index)
# Out:
# Index(['id', '일자', '시도명', '읍면동명', '거주인구', '근무인구', '방문인구', '총 유동인구', '평균 속도',
#        '평균 소요 시간', '평균 기온', '일강수량', '평균 풍속'],
#       dtype='object')
# RangeIndex(start=0, stop=9621, step=1)

# %%
# 행과 열의 수 출력
print(data.shape)
# Out:
# (9621, 13)

# %%
# 4. 데이터 프레임 확인
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9621 entries, 0 to 9620
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        9621 non-null   int64
#  1   일자        9621 non-null   object
#  2   시도명       9621 non-null   object
#  3   읍면동명      9621 non-null   object
#  4   거주인구      9621 non-null   float64
#  5   근무인구      9621 non-null   float64
#  6   방문인구      9621 non-null   float64
#  7   총 유동인구    9621 non-null   float64
#  8   평균 속도     9621 non-null   float64
#  9   평균 소요 시간  9621 non-null   float64
#  10  평균 기온     9621 non-null   float64
#  11  일강수량      9621 non-null   float64
#  12  평균 풍속     9621 non-null   float64
# dtypes: float64(9), int64(1), object(3)
# memory usage: 977.3+ KB
# None

# %%
# 5. 전체 컬럼목록 출력
print(data.columns)
# Out:
# Index(['id', '일자', '시도명', '읍면동명', '거주인구', '근무인구', '방문인구', '총 유동인구', '평균 속도',
#        '평균 소요 시간', '평균 기온', '일강수량', '평균 풍속'],
#       dtype='object')

# %%
# 6. 6번째 컬럼 출력
print(data.iloc[:,5])
# Out:
# 0        3418.266
# 1       10341.172
# 2       96920.834
# 3        6034.253
# 4        9403.969
#           ...
# 9616    16891.732
# 9617    26007.122
# 9618     3144.895
# 9619    29106.286
# 9620    65673.477
# Name: 근무인구, Length: 9621, dtype: float64

# %%
# 6번째 컬럼명 출력
print(data.columns[5])
# Out:
# 근무인구

# %%
# 7. 6번째 컬럼의 타입 출력
print(data.iloc[:,5].dtype)
# Out:
# float64

# %%
# 8. 6번째 컬럼의 3번째 값 출력
print(data.iloc[2,5])
# Out:
# 96920.834

# %%
# 9. 결측치 확인
print(data.isnull().sum())
# Out:
# id          0
# 일자          0
# 시도명         0
# 읍면동명        0
# 거주인구        0
# 근무인구        0
# 방문인구        0
# 총 유동인구      0
# 평균 속도       0
# 평균 소요 시간    0
# 평균 기온       0
# 일강수량        0
# 평균 풍속       0
# dtype: int64

# %%
# 10. 각 수치형 변수의 분포(사분위, 평균, 표준편차, 최대 , 최소) 확인
print(data.describe())
# Out:
#                  id          거주인구           근무인구           방문인구        총 유동인구  \
# count   9621.000000  9.621000e+03    9621.000000    9621.000000  9.621000e+03
# mean   27258.000000  3.174315e+05   35471.201510  195889.561802  5.487922e+05
# std     2777.487804  2.982079e+05   40381.214775  140706.090325  4.608802e+05
# min    22448.000000  9.305552e+03    1407.936000   11538.322000  2.225181e+04
# 25%    24853.000000  9.539939e+04   12074.498000   99632.153000  2.216910e+05
# 50%    27258.000000  2.221105e+05   21960.928000  152805.335000  3.866935e+05
# 75%    29663.000000  4.106671e+05   40192.032000  236325.109000  6.406918e+05
# max    32068.000000  1.364504e+06  263476.965000  723459.209000  2.066484e+06
#
#              평균 속도     평균 소요 시간        평균 기온         일강수량        평균 풍속
# count  9621.000000  9621.000000  9621.000000  9621.000000  9621.000000
# mean     41.109084    37.215873    13.550828     6.972426     2.753171
# std       8.758631    12.993786     7.745515    27.617260     1.498538
# min      24.333000    12.667000    -9.600000     0.000000     0.000000
# 25%      34.250000    27.889000     7.600000     0.000000     1.700000
# 50%      39.640000    34.500000    13.400000     0.000000     2.400000
# 75%      49.105000    46.176000    19.700000     1.500000     3.400000
# max     103.000000   172.200000    30.400000   587.500000    13.333000

# %%
# 11. 거주인구 컬럼값 출력
# print(data.loc[:,'거주인구'])
# print(data['거주인구'])
print(data.거주인구)
# Out:
# 0         32249.987
# 1        213500.997
# 2       1212382.218
# 3         33991.653
# 4        155036.925
#            ...
# 9616     228260.005
# 9617     459959.064
# 9618      28397.481
# 9619     348037.846
# 9620    1010643.372
# Name: 거주인구, Length: 9621, dtype: float64

# %%
# 12. 평균 속도의 4분위수(IQR) 값 출력(3사분위값 - 1사분위값)
q3 = data['평균 속도'].quantile(0.75)
q1 = data['평균 속도'].quantile(0.25)
print(q3 - q1)
# Out:
# 14.854999999999997

# %%
# 13. 읍면동명 유일값 출력
print(data.loc[:,'읍면동명'].unique())
# Out:
# ['도두동' '외도동' '이도2동' '일도1동' '대천동' '서홍동' '한경면' '송산동' '조천읍' '일도2동' '영천동'
#  '예래동' '대륜동' '삼도1동' '이호동' '건입동' '중앙동' '삼양동' '삼도2동' '이도1동' '남원읍' '대정읍'
#  '정방동' '효돈동' '아라동' '한림읍' '구좌읍' '용담1동' '오라동' '화북동' '연동' '표선면' '중문동' '성산읍'
#  '안덕면' '천지동' '노형동' '동홍동' '용담2동' '봉개동' '애월읍']

# %%
# 14. 읍면동명이 연동인 데이터 상위 5개 출력
print(data.loc[data['읍면동명'] == '연동'].head())
# Out:
#         id          일자  시도명 읍면동명         거주인구        근무인구        방문인구  \
# 48   22496  2018-01-05  제주시   연동  1079480.913  145011.847  565478.935
# 60   22508  2018-01-06  제주시   연동  1086062.807  108284.239  542647.886
# 77   22525  2018-01-10  제주시   연동  1100107.356  141226.833  561137.030
# 84   22532  2018-01-12  제주시   연동  1154536.331  136347.307  568157.988
# 237  22685  2018-01-24  제주시   연동  1091779.924  146250.120  630552.868
#
#           총 유동인구   평균 속도  평균 소요 시간  평균 기온  일강수량  평균 풍속
# 48   1789971.695  37.642    38.302   -1.7   3.5    0.0
# 60   1736994.932  38.962    36.604   -1.8   0.0    0.0
# 77   1802471.219  36.075    39.453   -5.1  18.5    3.0
# 84   1859041.626  32.925    47.226    0.0  10.0    0.0
# 237  1868582.913  35.868    41.396   -8.2   0.0    1.5

# %%
# 15. 일자컬럼을 통해 년,월,일 컬럼 추가
data['일자'] = pd.to_datetime(data['일자'])
data['년'] = data['일자'].dt.year
data['월'] = data['일자'].dt.month
data['일'] = data['일자'].dt.day
print(data[['일자', '년', '월', '일']])
# Out:
#              일자     년  월   일
# 0    2018-01-01  2018  1   1
# 1    2018-01-01  2018  1   1
# 2    2018-01-01  2018  1   1
# 3    2018-01-01  2018  1   1
# 4    2018-01-01  2018  1   1
# ...         ...   ... ..  ..
# 9616 2020-04-30  2020  4  30
# 9617 2020-04-30  2020  4  30
# 9618 2020-04-30  2020  4  30
# 9619 2020-04-30  2020  4  30
# 9620 2020-04-30  2020  4  30
#
# [9621 rows x 4 columns]

# %%
# 16. 시도명과 읍면동명만 추출해서 새로운 데이터프레임(df2)로 생성
data2 = data.loc[:, ['시도명', '읍면동명']]
print(data2.head())
# Out:
#     시도명  읍면동명
# 0   제주시   도두동
# 1   제주시   외도동
# 2   제주시  이도2동
# 3   제주시  일도1동
# 4  서귀포시   대천동

# %%
# 17. 시도명이 제주시인 데이터 개수 출력
print(len(data[data['시도명'] == '제주시']))
# Out:
# 5766

# %%
# 18. 연동의 2018년 1월 데이터 출력
print(data[(data['년'] == 2018) & (data['월'] == 1)])
# Out:
#         id         일자   시도명  읍면동명         거주인구       근무인구        방문인구  \
# 0    22448 2018-01-01   제주시   도두동    32249.987   3418.266  102709.092
# 1    22449 2018-01-01   제주시   외도동   213500.997  10341.172  112692.789
# 2    22450 2018-01-01   제주시  이도2동  1212382.218  96920.834  541194.481
# 3    22451 2018-01-01   제주시  일도1동    33991.653   6034.253   72155.919
# 4    22452 2018-01-01  서귀포시   대천동   155036.925   9403.969  150882.409
# ..     ...        ...   ...   ...          ...        ...         ...
# 327  22775 2018-01-31  서귀포시   남원읍   276581.982  25941.202  174633.302
# 328  22776 2018-01-31   제주시  이도1동   156487.951  34287.031  194312.084
# 329  22777 2018-01-31  서귀포시   송산동   202791.351  20455.133  113842.672
# 330  22778 2018-01-31   제주시   오라동   292901.956  37799.512  330504.658
# 331  22779 2018-01-31   제주시   조천읍   388923.463  46703.263  270292.608
#
#           총 유동인구   평균 속도  평균 소요 시간  평균 기온   일강수량  평균 풍속     년  월   일
# 0     138377.345  39.556    29.167  5.000  0.000    2.5  2018  1   1
# 1     336534.958  32.900    30.900  5.000  0.000    2.5  2018  1   1
# 2    1850497.533  29.538    35.692  2.900  0.000    2.4  2018  1   1
# 3     112181.825  30.000    23.500  2.900  0.000    2.4  2018  1   1
# 4     315323.303  41.583    14.375  5.100  0.000    2.3  2018  1   1
# ..           ...     ...       ...    ...    ...    ...   ... ..  ..
# 327   477156.486  52.343    41.429 -0.125  0.375    2.6  2018  1  31
# 328   385087.066  31.250    23.500  0.900  2.000    1.9  2018  1  31
# 329   337089.156  45.927    30.463  3.700  0.000    1.4  2018  1  31
# 330   661206.126  33.688    47.375  0.900  2.000    1.9  2018  1  31
# 331   705919.334  49.743    49.143 -0.200  1.333    2.0  2018  1  31
#
# [332 rows x 16 columns]

# %%
# 19. 거주인구순으로 정렬하고 인덱스 초기화
print(data.sort_values('거주인구').reset_index(drop=True))
# Out:
#          id         일자  시도명  읍면동명         거주인구        근무인구        방문인구  \
# 0     31156 2020-02-15  제주시  일도1동     9305.552    1407.936   11538.322
# 1     31068 2020-02-07  제주시  일도1동    14216.976    2743.319   27048.532
# 2     31032 2020-02-04  제주시  일도1동    14854.496    2728.161   24265.812
# 3     31055 2020-02-06  제주시  일도1동    15119.830    2684.037   24659.455
# 4     31181 2020-02-17  제주시  일도1동    18763.462    6538.807   51980.582
# ...     ...        ...  ...   ...          ...         ...         ...
# 9616  31406 2020-03-07  제주시   노형동  1317723.143   93083.000  395975.742
# 9617  25007 2018-08-23  제주시  이도2동  1323135.292  136586.658  432868.354
# 9618  25424 2018-10-06  제주시   노형동  1337831.209  103239.207  411238.071
# 9619  22828 2018-02-04  제주시   노형동  1354162.073   69622.474  354583.016
# 9620  22822 2018-02-04  제주시  이도2동  1364503.913   94263.214  434254.384
#
#            총 유동인구   평균 속도  평균 소요 시간  평균 기온   일강수량  평균 풍속     년   월   일
# 0       22251.810  35.250    22.000   14.3    1.0    1.9  2020   2  15
# 1       44008.827  34.000    24.250    3.7    0.0    1.8  2020   2   7
# 2       41848.469  34.000    22.750    1.4    0.0    2.3  2020   2   4
# 3       42463.322  35.500    22.000    0.0    0.0    1.7  2020   2   6
# 4       77282.852  33.250    24.250   -0.5    1.5    6.3  2020   2  17
# ...           ...     ...       ...    ...    ...    ...   ...  ..  ..
# 9616  1806781.885  41.523    29.733    4.3   12.0    1.5  2020   3   7
# 9617  1892590.304  28.769    37.731   25.0  405.0   11.8  2018   8  23
# 9618  1852308.487  38.701    30.172   14.7  141.0    2.3  2018  10   6
# 9619  1778367.563  31.904    38.289   -7.8   19.5    1.6  2018   2   4
# 9620  1893021.511  26.808    38.692   -3.4    3.0    5.1  2018   2   4
#
# [9621 rows x 16 columns]

# %%
# 20. 읍면동명에 1이 들어가 있는 데이터 출력
print(data[data.loc[:,'읍면동명'].str.find('1') > -1])
# Out:
#          id         일자  시도명  읍면동명        거주인구       근무인구        방문인구  \
# 3     22451 2018-01-01  제주시  일도1동   33991.653   6034.253   72155.919
# 13    22461 2018-01-01  제주시  삼도1동  220142.977  12879.914  137055.810
# 20    22468 2018-01-02  제주시  이도1동  160605.538  37956.727  185256.188
# 24    22472 2018-01-02  제주시  삼도1동  214133.270  19545.014  144542.957
# 39    22487 2018-01-04  제주시  용담1동  142776.813  13948.539  113542.070
# ...     ...        ...  ...   ...         ...        ...         ...
# 9583  32031 2020-04-27  제주시  일도1동   32784.484   5806.805   50501.538
# 9599  32047 2020-04-28  제주시  이도1동  184058.913  34137.428  198593.905
# 9605  32053 2020-04-29  제주시  이도1동  182810.071  32901.084  200885.525
# 9607  32055 2020-04-29  제주시  용담1동  142562.868   9597.254   92507.213
# 9613  32061 2020-04-30  제주시  이도1동  181868.115  23059.428  182154.330
#
#           총 유동인구   평균 속도  평균 소요 시간  평균 기온  일강수량  평균 풍속     년  월   일
# 3     112181.825  30.000    23.500    2.9   0.0    2.4  2018  1   1
# 13    370078.702  29.250    26.875    2.9   0.0    2.4  2018  1   1
# 20    383818.453  31.875    22.500    3.8   0.0    2.7  2018  1   2
# 24    378221.241  27.000    31.250    3.8   0.0    2.7  2018  1   2
# 39    270267.422  32.000    17.500    1.5   1.0    1.4  2018  1   4
# ...          ...     ...       ...    ...   ...    ...   ... ..  ..
# 9583   89092.828  34.000    22.750   11.2   0.0    2.5  2020  4  27
# 9599  416790.245  35.333    26.667   11.9   0.0    2.8  2020  4  28
# 9605  416596.681  35.000    27.667   12.7   0.0    2.8  2020  4  29
# 9607  244667.335  39.833    16.500   12.7   0.0    2.8  2020  4  29
# 9613  387081.873  35.667    28.222   16.9   0.0    2.8  2020  4  30
#
# [964 rows x 16 columns]

# %%
# 21. 거주인구 내림차순으로 정렬하고 인덱스 초기화
print(data.sort_values('거주인구', ascending=False).reset_index(drop=True))
# Out:
#          id         일자  시도명  읍면동명         거주인구        근무인구        방문인구  \
# 0     22822 2018-02-04  제주시  이도2동  1364503.913   94263.214  434254.384
# 1     22828 2018-02-04  제주시   노형동  1354162.073   69622.474  354583.016
# 2     25424 2018-10-06  제주시   노형동  1337831.209  103239.207  411238.071
# 3     25007 2018-08-23  제주시  이도2동  1323135.292  136586.658  432868.354
# 4     31406 2020-03-07  제주시   노형동  1317723.143   93083.000  395975.742
# ...     ...        ...  ...   ...          ...         ...         ...
# 9616  31181 2020-02-17  제주시  일도1동    18763.462    6538.807   51980.582
# 9617  31055 2020-02-06  제주시  일도1동    15119.830    2684.037   24659.455
# 9618  31032 2020-02-04  제주시  일도1동    14854.496    2728.161   24265.812
# 9619  31068 2020-02-07  제주시  일도1동    14216.976    2743.319   27048.532
# 9620  31156 2020-02-15  제주시  일도1동     9305.552    1407.936   11538.322
#
#            총 유동인구   평균 속도  평균 소요 시간  평균 기온   일강수량  평균 풍속     년   월   일
# 0     1893021.511  26.808    38.692   -3.4    3.0    5.1  2018   2   4
# 1     1778367.563  31.904    38.289   -7.8   19.5    1.6  2018   2   4
# 2     1852308.487  38.701    30.172   14.7  141.0    2.3  2018  10   6
# 3     1892590.304  28.769    37.731   25.0  405.0   11.8  2018   8  23
# 4     1806781.885  41.523    29.733    4.3   12.0    1.5  2020   3   7
# ...           ...     ...       ...    ...    ...    ...   ...  ..  ..
# 9616    77282.852  33.250    24.250   -0.5    1.5    6.3  2020   2  17
# 9617    42463.322  35.500    22.000    0.0    0.0    1.7  2020   2   6
# 9618    41848.469  34.000    22.750    1.4    0.0    2.3  2020   2   4
# 9619    44008.827  34.000    24.250    3.7    0.0    1.8  2020   2   7
# 9620    22251.810  35.250    22.000   14.3    1.0    1.9  2020   2  15
#
# [9621 rows x 16 columns]

# %%
# 22. 읍면동명이 연동이거나 외도동인 데이터 출력
print(data[(data['읍면동명'] == '연동') | (data['읍면동명'] == '외도동')])
# Out:
#          id         일자  시도명 읍면동명         거주인구        근무인구        방문인구  \
# 1     22449 2018-01-01  제주시  외도동   213500.997   10341.172  112692.789
# 37    22485 2018-01-04  제주시  외도동   199792.794   14111.559  123287.771
# 45    22493 2018-01-05  제주시  외도동   206508.498   13729.327  111508.270
# 48    22496 2018-01-05  제주시   연동  1079480.913  145011.847  565478.935
# 60    22508 2018-01-06  제주시   연동  1086062.807  108284.239  542647.886
# ...     ...        ...  ...  ...          ...         ...         ...
# 9446  31894 2020-04-16  제주시   연동  1049887.596  108747.470  398689.806
# 9535  31983 2020-04-23  제주시  외도동   278389.951   15006.174   99050.383
# 9578  32026 2020-04-26  제주시  외도동   281584.690   11018.575  106546.134
# 9612  32060 2020-04-29  제주시   연동  1008306.738  108163.467  471152.077
# 9620  32068 2020-04-30  제주시   연동  1010643.372   65673.477  447622.068
#
#            총 유동인구   평균 속도  평균 소요 시간  평균 기온  일강수량  평균 풍속     년  월   일
# 1      336534.958  32.900    30.900    5.0   0.0    2.5  2018  1   1
# 37     337192.124  30.150    33.950    3.3   0.5    1.8  2018  1   4
# 45     331746.096  30.000    35.450    4.2   4.0    3.1  2018  1   5
# 48    1789971.695  37.642    38.302   -1.7   3.5    0.0  2018  1   5
# 60    1736994.932  38.962    36.604   -1.8   0.0    0.0  2018  1   6
# ...           ...     ...       ...    ...   ...    ...   ... ..  ..
# 9446  1557324.872  41.157    27.471    9.6   0.0    1.6  2020  4  16
# 9535   392446.509  35.900    31.600   10.0   0.0    4.1  2020  4  23
# 9578   399149.399  38.050    28.450   12.2   0.0    1.6  2020  4  26
# 9612  1587622.282  39.784    28.784    8.3   0.0    1.1  2020  4  29
# 9620  1523938.917  40.863    27.765   14.1   0.0    4.8  2020  4  30
#
# [480 rows x 16 columns]

# %%
# 23. 총 유동인구가 총 유동인구의 평균보다 큰 데이터 출력
print(data[data['총 유동인구'] > data['총 유동인구'].mean()])
# Out:
#          id         일자   시도명  읍면동명         거주인구        근무인구        방문인구  \
# 2     22450 2018-01-01   제주시  이도2동  1212382.218   96920.834  541194.481
# 8     22456 2018-01-01   제주시   조천읍   425840.306   31366.810  338337.205
# 9     22457 2018-01-01   제주시  일도2동   721304.848   31018.811  252537.940
# 18    22466 2018-01-02   제주시   삼양동   444002.084   21070.328  100109.008
# 21    22469 2018-01-02   제주시   조천읍   412802.142   48971.498  255022.157
# ...     ...        ...   ...   ...          ...         ...         ...
# 9609  32057 2020-04-29   제주시  이도2동  1123450.401  143508.397  531825.028
# 9612  32060 2020-04-29   제주시    연동  1008306.738  108163.467  471152.077
# 9617  32065 2020-04-30   제주시   한림읍   459959.064   26007.122  249700.419
# 9619  32067 2020-04-30  서귀포시   안덕면   348037.846   29106.286  251129.660
# 9620  32068 2020-04-30   제주시    연동  1010643.372   65673.477  447622.068
#
#            총 유동인구   평균 속도  평균 소요 시간   평균 기온  일강수량  평균 풍속     년  월   일
# 2     1850497.533  29.538    35.692   2.900   0.0  2.400  2018  1   1
# 8      795544.320  51.629    47.429   1.967   0.0  3.367  2018  1   1
# 9     1004861.600  29.727    38.273   2.900   0.0  2.400  2018  1   1
# 18     565181.421  31.571    17.000   2.800   0.0  1.900  2018  1   2
# 21     716795.797  51.771    47.229   2.800   0.0  1.900  2018  1   2
# ...           ...     ...       ...     ...   ...    ...   ... ..  ..
# 9609  1798783.826  32.844    42.562  12.700   0.0  2.800  2020  4  29
# 9612  1587622.282  39.784    28.784   8.300   0.0  1.100  2020  4  29
# 9617   735666.605  48.609    61.377  18.000   0.0  4.350  2020  4  30
# 9619   628273.792  46.595    49.189  17.600   0.0  3.500  2020  4  30
# 9620  1523938.917  40.863    27.765  14.100   0.0  4.800  2020  4  30
#
# [3594 rows x 16 columns]

# %%
# 24. id가 22457인 평균 속도를 nan값으로 변경
import numpy as np
data.loc[data['id'] == 22457, '평균 속도'] = np.nan
print(data[data['id'] == 22457])
# Out:
#       id         일자  시도명  읍면동명        거주인구       근무인구       방문인구     총 유동인구  \
# 9  22457 2018-01-01  제주시  일도2동  721304.848  31018.811  252537.94  1004861.6
#
#    평균 속도  평균 소요 시간  평균 기온  일강수량  평균 풍속     년  월  일
# 9    NaN    38.273    2.9   0.0    2.4  2018  1  1

# %%
# 25. 평균 속도의 결측치 확인
print(data['평균 속도'].isnull().sum())
# Out:
# 1

# %%
# 26. 평균속도의 결측치를 평균속도의 평균으로 치환
data.loc[data['평균 속도'].isnull(), '평균 속도'] = data['평균 속도'].mean()
print(data['평균 속도'].isnull().sum())
# Out:
# 0

# %%
data['평균 속도'] = data['평균 속도'].fillna(data['평균 속도'].mean()).isnull().sum()

# %%
# 27. 읍면동명 데이터 중 읍 데이터의 갯수 출력
#'파이썬'.endswith('싼')
print(len(data[data['읍면동명'].str[-1] == '읍']))
print(len(data[data['읍면동명'].str.endswith('읍')]))
# Out:
# 1685
# 1685

# %%
# 28. 읍면동명이 3자인 데이터 갯수 출력
# print(len(data['읍면동명'].str))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [56], in <cell line: 2>()
#       1 # 28. 읍면동명이 3자인 데이터 갯수 출력
# ----> 2 print(len(data['읍면동명'].str))
#
# TypeError: object of type 'StringMethods' has no len()

# %%
# 29. 시도명별 읍면동명 개수 출력

# %%
# 30. 시도명별 읍면동명별 거주인구 평균

# %%
# 31. 시도명별 읍면동명별 거주인구 평균, 최소, 최대 한번에 출력

# %%
# 32. 제주시의 읍면동명별 거주인구 평균, 최소, 최대 출력

# %%
# 33. 시도명2 컬럼을 생성해 제주시는 0, 서귀포시는 1로 저장

# %%
# 34. 읍면동2 컬럼을 생성해 읍은 0, 면은 1, 동은 2로 저장

# %%
# 35. 요일컬럼 추가
