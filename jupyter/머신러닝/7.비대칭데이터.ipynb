# %% [markdown]
# ### 비대칭 데이터
# * 불균형 데이터, imbalanced data
# * target 데이터의 비율이 차이가 많이 나는 경우 (암 양/악성, 반도체 고장여부)
# * 정확도는 높지만, 재현율이 낮아지는 현상
#
# #### 해결방법
# * over-sampling : 적은 데이터를 증가(많이 사용)
# * under-sampling : 많은 데이터를 제거

# %%
# !pip install imbalanced-learn
# Out:
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ...

# %%
# 오버샘플링
from imblearn.over_sampling import RandomOverSampler, SMOTE

# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
data = cancer['data']
target = cancer['target']
df = pd.DataFrame(data=data, columns=cancer['feature_names'])
df['target'] = target

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
print(cancer['DESCR'])
# Out:
# .. _breast_cancer_dataset:
#
# Breast cancer wisconsin (diagnostic) dataset
# --------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
#         The mean, standard error, and "worst" or largest (mean of the three
#         worst/largest values) of these features were computed for each image,
# ...

# %%
df['target'].value_counts()
# Out:
# 1    357
# 0    212
# Name: target, dtype: int64

# %%
df0 = df[df['target']==0][:10] # 악성
df1 = df[df['target']==1]
df = pd.concat([df0, df1])

# %%
df['target'].value_counts()
# Out:
# 1    357
# 0     10
# Name: target, dtype: int64

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(df.drop('target', axis=1), 
                                                   df['target'],
                                                   random_state=32,
                                                   stratify=df['target'])

# %%
train_x.shape, test_x.shape, train_y.shape, test_y.shape
# Out:
# ((275, 30), (92, 30), (275,), (92,))

# %%
train_y.value_counts()
# Out:
# 1    268
# 0      7
# Name: target, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
model = DecisionTreeClassifier()
model.fit(train_x, train_y)
pred = model.predict(test_x)
accuracy_score(test_y, pred)
# Out:
# 1.0

# %%
from sklearn.metrics import classification_report, confusion_matrix
confusion_matrix(test_y, pred)
# Out:
# array([[89,  0],
#        [ 0, 90]], dtype=int64)

# %%
print(classification_report(test_y, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        89
#            1       1.00      1.00      1.00        90
#
#     accuracy                           1.00       179
#    macro avg       1.00      1.00      1.00       179
# weighted avg       1.00      1.00      1.00       179

# %%
ros = RandomOverSampler()
data, target = ros.fit_resample(df.drop('target', axis=1), df['target'])

# %%
ros_df = pd.concat([data, target], axis=1)
ros_df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 709        17.99         10.38          122.80     1001.0          0.11840
# 710        20.57         17.77          132.90     1326.0          0.08474
# 711        17.99         10.38          122.80     1001.0          0.11840
# 712        12.45         15.70           82.57      477.1          0.12780
# 713        13.71         20.83           90.20      577.9          0.11890
#
# ...

# %%
ros_df['target'].value_counts()
# Out:
# 0    357
# 1    357
# Name: target, dtype: int64

# %%
train_x, test_x, train_y, test_y = train_test_split(df.drop('target', axis=1), 
                                                   df['target'],
                                                   random_state=32,
                                                   stratify=df['target'])
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
model = DecisionTreeClassifier()
model.fit(train_x, train_y)
pred = model.predict(test_x)
accuracy_score(test_y, pred)
# Out:
# 0.9782608695652174

# %%
# SMOTE (Synthetic Minority Over-sampling Techique)
# 점과 점 사이의 가까운 새로운 점 생성
from imblearn.over_sampling import SMOTE
sm = SMOTE()
sm.fit_resample(df.drop('target', axis=1), df['target'])
sm_df = pd.concat([data, target], axis=1)
sm_df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 709        17.99         10.38          122.80     1001.0          0.11840
# 710        20.57         17.77          132.90     1326.0          0.08474
# 711        17.99         10.38          122.80     1001.0          0.11840
# 712        12.45         15.70           82.57      477.1          0.12780
# 713        13.71         20.83           90.20      577.9          0.11890
#
# ...

# %%
sm_df['target'].value_counts()
# Out:
# 0    357
# 1    357
# Name: target, dtype: int64

# %%
train_x, test_x, train_y, test_y = train_test_split(sm_df.drop('target', axis=1), 
                                                   sm_df['target'],
                                                   random_state=32,
                                                   stratify=sm_df['target'])

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
model = DecisionTreeClassifier()
model.fit(train_x, train_y)
pred = model.predict(test_x)
accuracy_score(test_y, pred)
# Out:
# 1.0

# %%
confusion_matrix(test_y, pred)
# Out:
# array([[89,  0],
#        [ 0, 90]], dtype=int64)

# %%
print(classification_report(test_y, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        89
#            1       1.00      1.00      1.00        90
#
#     accuracy                           1.00       179
#    macro avg       1.00      1.00      1.00       179
# weighted avg       1.00      1.00      1.00       179
